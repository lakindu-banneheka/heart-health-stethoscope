# %% [markdown]
# Model V2 - Fix over-fitting by dropouts and regularization

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

# %%
DATASET_PATH="data_10.json"

# %%
# load data
def load_data(dataset_path):
    with open(dataset_path, "r") as fp:
        data = json.load(fp)

    # convert lists into numpy arrays 
    inputs = np.array(data["mfcc"])
    targets = np.array(data["labels"])

    return inputs, targets

# %%
inputs, targets = load_data(DATASET_PATH)

# %%
# split the data training & test sets
inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs,
                                                                          targets,
                                                                          test_size=0.3
                                                                         )

# %%
# build the newtwork architecture 
model = keras.Sequential([
    # input layer
    keras.Input(shape=(inputs.shape[1], inputs.shape[2])),
    keras.layers.Flatten(),

    # 1st hidden layer
    keras.layers.Dense(512, activation="relu", kernel_regularizer=keras.regularizers.l2(0.0001)),
    keras.layers.Dropout(0.4),

    # 2nd hidden layer
    keras.layers.Dense(256, activation="relu", kernel_regularizer=keras.regularizers.l2(0.0001)),
    keras.layers.Dropout(0.4),

    # 3rd hidden layer
    keras.layers.Dense(64, activation="relu", kernel_regularizer=keras.regularizers.l2(0.0001)),
    keras.layers.Dropout(0.3),

    # output layer
    keras.layers.Dense(3, activation="softmax")
])

# %%
# compile network
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, 
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"]
             )

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 1690)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         865,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,013,763 (3.87 MB)
#  Trainable params: 1,013,763 (3.87 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# train network 
history = model.fit(
    inputs_train, 
    targets_train,  
    validation_data=(inputs_test, targets_test),
    epochs=50,
    batch_size=32
)
# Out:
# Epoch 1/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.4882 - loss: 155.9670 - val_accuracy: 0.7858 - val_loss: 10.3583
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7176 - loss: 22.5550 - val_accuracy: 0.8698 - val_loss: 2.9031
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7475 - loss: 13.2261 - val_accuracy: 0.8568 - val_loss: 1.2119
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7503 - loss: 10.4098 - val_accuracy: 0.8686 - val_loss: 1.1894
# Epoch 5/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7926 - loss: 7.2235 - val_accuracy: 0.8343 - val_loss: 0.9853
# Epoch 6/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7817 - loss: 5.4096 - val_accuracy: 0.8686 - val_loss: 0.8520
# Epoch 7/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7843 - loss: 5.0535 - val_accuracy: 0.8462 - val_loss: 0.8013
# Epoch 8/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8185 - loss: 3.3942 - val_accuracy: 0.8805 - val_loss: 0.6410
# Epoch 9/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8079 - loss: 3.5469 - val_accuracy: 0.8639 - val_loss: 0.7244
# Epoch 10/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8114 - loss: 2.7874 - val_accuracy: 0.8828 - val_loss: 0.6719
# Epoch 11/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8157 - loss: 2.6180 - val_accuracy: 0.8663 - val_loss: 0.7702
# Epoch 12/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8132 - loss: 2.3277 - val_accuracy: 0.8793 - val_loss: 0.5982
# Epoch 13/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8186 - loss: 1.7922 - val_accuracy: 0.8722 - val_loss: 0.6736
# Epoch 14/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8172 - loss: 1.9643 - val_accuracy: 0.8592 - val_loss: 0.5827
# Epoch 15/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8253 - loss: 1.3285 - val_accuracy: 0.8580 - val_loss: 0.6846
# Epoch 16/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8118 - loss: 1.5081 - val_accuracy: 0.8580 - val_loss: 0.7443
# Epoch 17/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8077 - loss: 1.4319 - val_accuracy: 0.8391 - val_loss: 0.6564
# Epoch 18/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8223 - loss: 1.1018 - val_accuracy: 0.8509 - val_loss: 0.5178
# Epoch 19/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8064 - loss: 1.1927 - val_accuracy: 0.8734 - val_loss: 0.4697
# Epoch 20/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8070 - loss: 0.9777 - val_accuracy: 0.8107 - val_loss: 0.5493
# Epoch 21/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7834 - loss: 0.9296 - val_accuracy: 0.8438 - val_loss: 0.6583
# Epoch 22/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8194 - loss: 0.7601 - val_accuracy: 0.8166 - val_loss: 0.6422
# Epoch 23/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8121 - loss: 0.8046 - val_accuracy: 0.8722 - val_loss: 0.5078
# Epoch 24/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8259 - loss: 0.9493 - val_accuracy: 0.8627 - val_loss: 0.5914
# Epoch 25/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8385 - loss: 0.6311 - val_accuracy: 0.8544 - val_loss: 0.5580
# Epoch 26/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8578 - loss: 0.6563 - val_accuracy: 0.8746 - val_loss: 0.4839
# Epoch 27/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8422 - loss: 0.6344 - val_accuracy: 0.8817 - val_loss: 0.5041
# Epoch 28/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8445 - loss: 0.6485 - val_accuracy: 0.8746 - val_loss: 0.4868
# Epoch 29/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8489 - loss: 0.6893 - val_accuracy: 0.8698 - val_loss: 0.4741
# Epoch 30/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8391 - loss: 0.5977 - val_accuracy: 0.8757 - val_loss: 0.4970
# Epoch 31/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8484 - loss: 0.6117 - val_accuracy: 0.8828 - val_loss: 0.4617
# Epoch 32/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8507 - loss: 0.6521 - val_accuracy: 0.8734 - val_loss: 0.5303
# Epoch 33/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8677 - loss: 0.5680 - val_accuracy: 0.8793 - val_loss: 0.4884
# Epoch 34/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8629 - loss: 0.5273 - val_accuracy: 0.8757 - val_loss: 0.4465
# Epoch 35/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8376 - loss: 0.6101 - val_accuracy: 0.8805 - val_loss: 0.4263
# Epoch 36/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8513 - loss: 0.5080 - val_accuracy: 0.8805 - val_loss: 0.4230
# Epoch 37/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8719 - loss: 0.4843 - val_accuracy: 0.8793 - val_loss: 0.4834
# Epoch 38/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8593 - loss: 0.5376 - val_accuracy: 0.8781 - val_loss: 0.4989
# Epoch 39/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8614 - loss: 0.5292 - val_accuracy: 0.8757 - val_loss: 0.5083
# Epoch 40/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8439 - loss: 0.5078 - val_accuracy: 0.8722 - val_loss: 0.4893
# Epoch 41/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8751 - loss: 0.4960 - val_accuracy: 0.8840 - val_loss: 0.4299
# Epoch 42/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8465 - loss: 0.4777 - val_accuracy: 0.8899 - val_loss: 0.4552
# Epoch 43/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8670 - loss: 0.4757 - val_accuracy: 0.8888 - val_loss: 0.4535
# Epoch 44/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.8492 - loss: 0.4835 - val_accuracy: 0.8911 - val_loss: 0.4429
# Epoch 45/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8618 - loss: 0.4580 - val_accuracy: 0.8722 - val_loss: 0.4319
# Epoch 46/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8577 - loss: 0.4965 - val_accuracy: 0.8840 - val_loss: 0.4281
# Epoch 47/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8586 - loss: 0.4366 - val_accuracy: 0.8888 - val_loss: 0.4256
# Epoch 48/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8526 - loss: 0.4836 - val_accuracy: 0.8828 - val_loss: 0.4341
# Epoch 49/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8703 - loss: 0.4232 - val_accuracy: 0.8781 - val_loss: 0.4246
# Epoch 50/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8686 - loss: 0.4220 - val_accuracy: 0.8817 - val_loss: 0.4109

# %%
# Plot Training History for Accuracy
plt.figure(figsize=(8, 4))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Model Accuracy')
plt.show()

# Plot Training History for Loss
plt.figure(figsize=(8, 4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Model Loss')
plt.show()

# %%
# as a keras model
model.save('models/heart_sound_model_v2_0001.keras')
# as a h5 model
model.save("models/heart_sound_model_v2_0001.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
