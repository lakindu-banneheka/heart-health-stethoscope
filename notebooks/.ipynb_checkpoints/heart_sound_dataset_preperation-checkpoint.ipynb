# %%
import os
import librosa
import math
import json

# %%
DATASET_PATH = "data"
JSON_PATH = "data_0_0003.json"
SAMPLE_RATE = 22050
DURATION = 5 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * DURATION

# %%
def save_mfcc(dataset_path, json_path, n_mfcc=13, n_fft=2048, hop_length=512, num_segments=1):

    # Dictionary to store data
    data = {
        "mapping": [],
        "mfcc": [],
        "labels": []
    }

    num_samples_per_segment = int(SAMPLES_PER_TRACK / num_segments);
    expected_num_mfcc_vectors_per_segment = math.ceil(num_samples_per_segment / hop_length) # ceil => ex:- 1.2 -> 2

    # loop through all the genres
    for i, (dir_path, dir_names, file_names) in enumerate(os.walk(dataset_path)):

        # ensure we are not at the root class
        if dir_path is not dataset_path:

            # save the semantic label
            dir_path_components = dir_path.split("\\")
            semantic_label = dir_path_components[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing {}".format(semantic_label))

            # Process files for a specific genre
            for f in file_names:
                
                # load audio file
                file_path = os.path.join(dir_path, f)
                # signal, sr = librosa.load(file_path, sr=SAMPLE_RATE, duration=DURATION)
                
                try:
                    signal, sr = librosa.load(file_path, sr=SAMPLE_RATE, duration=DURATION)
                except Exception as e:
                    # Handle the exception
                    print(f"An error occurred: {e}")
                    continue
                
                # process segments, extracting MFCCS and storing the data
                for s in range(num_segments):
                    start_sample = num_samples_per_segment * s # 
                    finish_sample = start_sample + num_samples_per_segment
                    
 
                    mfcc = librosa.feature.mfcc(y=signal[start_sample:finish_sample],
                                                sr=sr,
                                                n_fft=n_fft,
                                                n_mfcc=n_mfcc,
                                                hop_length=hop_length
                                               )
                    mfcc = mfcc.T

                    # store MFCC for segment if it has the expected length
                    # print(f"SAMPLES_PER_TRACK: {SAMPLES_PER_TRACK} - {len(mfcc)}")
                    
                    if len(mfcc) == expected_num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)
                        print("label: {}, {}, segment:{}".format(i-1, file_path, s+1))

    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)
        print(f"\n✅ MFCC data successfully saved to {json_path}")

# %%
def save_mfcc_without_seg(dataset_path, json_path, n_mfcc=13, n_fft=2048, hop_length=512):

    # Dictionary to store data
    data = {
        "mapping": [],
        "mfcc": [],
        "labels": []
    }

    # loop through all the genres
    for i, (dir_path, dir_names, file_names) in enumerate(os.walk(dataset_path)):

        # ensure we are not at the root class
        if dir_path is not dataset_path:

            # save the semantic label
            dir_path_components = dir_path.split("\\")
            semantic_label = dir_path_components[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing {}".format(semantic_label))

            # Process files for a specific genre
            for f in file_names:
                
                # load audio file
                file_path = os.path.join(dir_path, f)
                # signal, sr = librosa.load(file_path, sr=SAMPLE_RATE, duration=DURATION)
                
                try:
                    signal, sr = librosa.load(file_path, sr=SAMPLE_RATE, duration=DURATION)
                except Exception as e:
                    # Handle the exception
                    print(f"An error occurred: {e}")
                    continue
                
                # process extracting MFCCS and storing the data
                mfcc = librosa.feature.mfcc(y=signal,
                                                sr=sr,
                                                n_fft=n_fft,
                                                n_mfcc=n_mfcc,
                                                hop_length=hop_length
                                               )
                mfcc = mfcc.T

                # Store MFCC if it has the expected length
                print(f"SAMPLES_PER_TRACK: {SAMPLES_PER_TRACK} - {len(mfcc)} :: {mfcc.shape}")
                # if len(mfcc) == SAMPLES_PER_TRACK:
                data["mfcc"].append(mfcc.tolist())
                data["labels"].append(i-1)
                print("label: {}, {}".format(i-1, file_path))

    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)
        print(f"\n✅ MFCC data successfully saved to {json_path}")

# %%
save_mfcc_without_seg(DATASET_PATH, JSON_PATH)
# Out:
# Processing abnormal
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0003.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0004.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0005.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0006.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0008.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0010.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0013.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0014.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0015.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0017.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0018.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0020.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0021.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0022.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0023.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0024.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0026.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0030.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0031.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0033.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0034.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0036.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0037.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0039.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0040.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0041.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0042.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0043.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0044.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0045.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0046.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0047.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0048.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0051.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0052.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0054.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0056.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0057.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0058.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0059.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0060.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0061.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0062.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0063.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0064.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0065.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0066.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0067.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0072.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0073.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0074.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0075.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0076.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0077.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0078.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0079.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0082.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0083.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0084.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0087.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0089.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0090.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0092.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0095.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0096.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0097.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0098.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0099.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0100.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0101.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0103.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0104.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0107.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0110.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0111.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0112.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0113.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0114.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0115.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0116.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0117.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0119.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0120.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0121.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0122.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0123.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0124.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0126.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0128.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0130.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0131.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0132.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0133.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0134.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0135.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0137.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0138.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0142.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0143.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0144.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0145.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0146.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0147.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0148.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0149.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0150.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0151.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0152.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0156.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0157.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0158.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0159.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0160.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0162.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0163.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0164.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0166.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0167.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0168.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0169.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0170.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0172.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0173.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0174.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0175.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0176.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0177.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0180.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0182.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0183.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0186.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0187.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0188.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0190.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0191.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0192.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0194.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0197.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0198.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0200.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0201.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0202.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0203.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0205.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0206.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0207.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0209.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0213.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0214.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0215.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0216.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0217.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0218.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0219.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0220.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\a0221.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrahls__201101070953.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrahls__201101091153.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrahls__201101152255.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrahls__201101160804.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrahls__201101160808.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrahls__201101241423.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrahls__201101241433.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrahls__201102070251.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrahls__201102071835.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrahls__201102241217.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrahls__201103150114.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrahls__201103182227.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrahls__201103200218.wav
# SAMPLES_PER_TRACK: 110250 - 41 :: (41, 13)
# label: 0, data\abnormal\extrahls__201104021355.wav
# SAMPLES_PER_TRACK: 110250 - 84 :: (84, 13)
# label: 0, data\abnormal\extrahls__201104140118.wav
# SAMPLES_PER_TRACK: 110250 - 140 :: (140, 13)
# label: 0, data\abnormal\extrahls__201104270458.wav
# SAMPLES_PER_TRACK: 110250 - 71 :: (71, 13)
# label: 0, data\abnormal\extrahls__201104270459.wav
# SAMPLES_PER_TRACK: 110250 - 202 :: (202, 13)
# label: 0, data\abnormal\extrastole__127_1306764300147_C2.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrastole__128_1306344005749_A.wav
# SAMPLES_PER_TRACK: 110250 - 111 :: (111, 13)
# label: 0, data\abnormal\extrastole__134_1306428161797_C1.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrastole__138_1306762146980_B.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrastole__140_1306519735121_D.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrastole__144_1306522408528_B.wav
# SAMPLES_PER_TRACK: 110250 - 145 :: (145, 13)
# label: 0, data\abnormal\extrastole__144_1306522408528_B1.wav
# SAMPLES_PER_TRACK: 110250 - 173 :: (173, 13)
# label: 0, data\abnormal\extrastole__148_1306768801551_B.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrastole__151_1306779785624_B.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrastole__153_1306848820671_C.wav
# SAMPLES_PER_TRACK: 110250 - 104 :: (104, 13)
# label: 0, data\abnormal\extrastole__154_1306935608852_D2.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrastole__163_1307104470471_C.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrastole__179_1307990076841_C.wav
# SAMPLES_PER_TRACK: 110250 - 216 :: (216, 13)
# label: 0, data\abnormal\extrastole__184_1308073010307_A.wav
# SAMPLES_PER_TRACK: 110250 - 81 :: (81, 13)
# label: 0, data\abnormal\extrastole__190_1308076920011_C.wav
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 save_mfcc_without_seg(DATASET_PATH, JSON_PATH)
#
# Cell In[74], line 30, in save_mfcc_without_seg(dataset_path, json_path, n_mfcc, n_fft, hop_length)
#      27 # signal, sr = librosa.load(file_path, sr=SAMPLE_RATE, duration=DURATION)
#      29 try:
# ---> 30     signal, sr = librosa.load(file_path, sr=SAMPLE_RATE, duration=DURATION)
#      31 except Exception as e:
#      32     # Handle the exception
#      33     print(f"An error occurred: {e}")
#
# File ~\anaconda3\Lib\site-packages\librosa\core\audio.py:176, in load(path, sr, mono, offset, duration, dtype, res_type)
#     173 else:
#     174     # Otherwise try soundfile first, and then fall back if necessary
#     175     try:
# --> 176         y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     178     except sf.SoundFileRuntimeError as exc:
#     179         # If soundfile failed, try audioread instead
#     180         if isinstance(path, (str, pathlib.PurePath)):
#
# File ~\anaconda3\Lib\site-packages\librosa\core\audio.py:209, in __soundfile_load(path, offset, duration, dtype)
#     206     context = path
#     207 else:
#     208     # Otherwise, create the soundfile object
# --> 209     context = sf.SoundFile(path)
#     211 with context as sf_desc:
#     212     sr_native = sf_desc.samplerate
#
# File ~\anaconda3\Lib\site-packages\soundfile.py:690, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd, compression_level, bitrate_mode)
#     687 self._bitrate_mode = bitrate_mode
#     688 self._info = _create_info_struct(file, mode, samplerate, channels,
#     689                                  format, subtype, endian)
# --> 690 self._file = self._open(file, mode_int, closefd)
#     691 if set(mode).issuperset('r+') and self.seekable():
#     692     # Move write position to 0 (like in Python file objects)
#     693     self.seek(0)
#
# File ~\anaconda3\Lib\site-packages\soundfile.py:1254, in SoundFile._open(self, file, mode_int, closefd)
#    1252         else:
#    1253             file = file.encode(_sys.getfilesystemencoding())
# -> 1254     file_ptr = openfunction(file, mode_int, self._info)
#    1255 elif isinstance(file, int):
#    1256     file_ptr = _snd.sf_open_fd(file, mode_int, self._info, closefd)
#
# KeyboardInterrupt:
