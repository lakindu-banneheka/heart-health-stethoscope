# %% [markdown]
#  CNN Architecture for the model
#
# - Test set accuracy: **0.8949**
# - Training accuracy: **0.9575** – loss: **0.1100**
# - Validation accuracy: **0.9054** – val_loss: **0.2191**

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

# %%
DATASET_PATH="data_10.json"

# load data from json
with open(DATASET_PATH, "r") as fp:
    data = json.load(fp)

# convert lists into numpy arrays 
x = np.array(data["mfcc"])
y = np.array(data["labels"])

# %%
# create train, validation and test sets
TEST_SIZE=0.25
VAL_SIZE=0.2 

# create train/test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=TEST_SIZE)
    
# create train/val split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=VAL_SIZE)

# 3d array -> 4d array ( , , , 1 )
x_train = x_train[..., np.newaxis] # 4d -> (num_samples, 130, 13, 1) 
x_val = x_val[..., np.newaxis] 
x_test = x_test[..., np.newaxis]

# %%
# input shape
input_shape = (x_train.shape[1], x_train.shape[2], x_train.shape[3])
input_shape
# Out:
# (130, 13, 1)

# %%
# Build CNN network
model = keras.Sequential()
model.add(keras.layers.Input(shape=input_shape))

# 1st con layer
model.add(keras.layers.Conv2D(32, (3, 3), activation='relu')) # num_kernels, grid_size_of_kernel, ...
model.add(keras.layers.MaxPool2D((3,3), strides=(2,2), padding='same')) # pool_size
model.add(keras.layers.BatchNormalization()) # normalize the layers and models gonna be faster 

# 2nd con layer
model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model.add(keras.layers.MaxPool2D((3,3), strides=(2,2), padding='same'))
model.add(keras.layers.BatchNormalization())

# 3rd con layer
model.add(keras.layers.Conv2D(32, (2, 2), activation='relu', input_shape=input_shape))
model.add(keras.layers.MaxPool2D((2,2), strides=(2,2), padding='same'))
model.add(keras.layers.BatchNormalization())

# Flatten the output and feed it into dense layer
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dropout(0.3))

# output layer
model.add(keras.layers.Dense(3, activation='softmax'))

# %%
# compile the network
# compile network
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, 
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"]
             )

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 128, 11, 32)         │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 64, 6, 32)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 64, 6, 32)           │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 62, 4, 32)           │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 31, 2, 32)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 31, 2, 32)           │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 30, 1, 32)           │           4,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 15, 1, 32)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 15, 1, 32)           │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 480)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │          30,784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 45,059 (176.01 KB)
#  Trainable params: 44,867 (175.26 KB)
#  Non-trainable params: 192 (768.00 B)

# %%
# train the CNN 
history = model.fit(
    x_train, 
    y_train,  
    validation_data=(x_val, y_val),
    epochs=30,
    batch_size=32
)
# Out:
# Epoch 1/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.5614 - loss: 1.0865 - val_accuracy: 0.8203 - val_loss: 0.5567
# Epoch 2/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8308 - loss: 0.5219 - val_accuracy: 0.8511 - val_loss: 0.3939
# Epoch 3/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8327 - loss: 0.4033 - val_accuracy: 0.8582 - val_loss: 0.3211
# Epoch 4/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8537 - loss: 0.3614 - val_accuracy: 0.8629 - val_loss: 0.2990
# Epoch 5/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8618 - loss: 0.3091 - val_accuracy: 0.8771 - val_loss: 0.2768
# Epoch 6/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8820 - loss: 0.2651 - val_accuracy: 0.8747 - val_loss: 0.2626
# Epoch 7/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8763 - loss: 0.2721 - val_accuracy: 0.8794 - val_loss: 0.2574
# Epoch 8/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8742 - loss: 0.2774 - val_accuracy: 0.8771 - val_loss: 0.2510
# Epoch 9/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8987 - loss: 0.2217 - val_accuracy: 0.8629 - val_loss: 0.2558
# Epoch 10/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8995 - loss: 0.2213 - val_accuracy: 0.8629 - val_loss: 0.2507
# Epoch 11/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8922 - loss: 0.2269 - val_accuracy: 0.8865 - val_loss: 0.2470
# Epoch 12/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9107 - loss: 0.2038 - val_accuracy: 0.8842 - val_loss: 0.2367
# Epoch 13/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9111 - loss: 0.1838 - val_accuracy: 0.8842 - val_loss: 0.2278
# Epoch 14/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9152 - loss: 0.1878 - val_accuracy: 0.8818 - val_loss: 0.2352
# Epoch 15/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9051 - loss: 0.2007 - val_accuracy: 0.8889 - val_loss: 0.2325
# Epoch 16/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9310 - loss: 0.1624 - val_accuracy: 0.8913 - val_loss: 0.2266
# Epoch 17/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9288 - loss: 0.1733 - val_accuracy: 0.8865 - val_loss: 0.2356
# Epoch 18/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9399 - loss: 0.1697 - val_accuracy: 0.8913 - val_loss: 0.2237
# Epoch 19/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9255 - loss: 0.1680 - val_accuracy: 0.8865 - val_loss: 0.2231
# Epoch 20/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9332 - loss: 0.1496 - val_accuracy: 0.8842 - val_loss: 0.2196
# Epoch 21/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9286 - loss: 0.1636 - val_accuracy: 0.9078 - val_loss: 0.2278
# Epoch 22/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9386 - loss: 0.1458 - val_accuracy: 0.9054 - val_loss: 0.2233
# Epoch 23/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9499 - loss: 0.1402 - val_accuracy: 0.9054 - val_loss: 0.2196
# Epoch 24/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9504 - loss: 0.1431 - val_accuracy: 0.8960 - val_loss: 0.2205
# Epoch 25/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9568 - loss: 0.1262 - val_accuracy: 0.8960 - val_loss: 0.2166
# Epoch 26/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9568 - loss: 0.1173 - val_accuracy: 0.8936 - val_loss: 0.2215
# Epoch 27/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9505 - loss: 0.1178 - val_accuracy: 0.8842 - val_loss: 0.2283
# Epoch 28/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9498 - loss: 0.1312 - val_accuracy: 0.8936 - val_loss: 0.2217
# Epoch 29/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9558 - loss: 0.1196 - val_accuracy: 0.9173 - val_loss: 0.2234
# Epoch 30/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9575 - loss: 0.1100 - val_accuracy: 0.9054 - val_loss: 0.2191

# %%
# evaluate the CNN on the test_set
test_error, test_accuracy = model.evaluate(x_test, y_test, verbose=1)
print(f"Accuracy on test set is: {test_accuracy}")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8827 - loss: 0.2411
# Accuracy on test set is: 0.8948863744735718

# %%
# Plot Training History for Accuracy
plt.figure(figsize=(8, 4))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Model Accuracy')
plt.show()

# Plot Training History for Loss
plt.figure(figsize=(8, 4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Model Loss')
plt.show()

# %%
# make predictions on a sample test data
X = x_test[300]
Y = y_test[300]

X = X[np.newaxis, ...]
prediction = model.predict(X)

# extract index with max value
predicted_index = np.argmax(prediction, axis=1) 

print(f"Expected index: {Y}, \nPredicted Index: {predicted_index[0]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Expected index: 1,
# Predicted Index: 1

# %%
# as a keras model
model.save('models/heart_sound_model_v3_0001.keras')
# as a h5 model
model.save("models/heart_sound_model_v3_0001.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
